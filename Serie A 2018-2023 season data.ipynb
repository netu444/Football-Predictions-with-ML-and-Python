# %%
import requests

# %%
standings_url= "https://fbref.com/en/comps/11/Serie-A-Stats"

# %%
data=requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table=soup.select('table.stats_table')[0]

# %%
links= standings_table.find_all('a')

# %%
links= [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/d609edc0/Internazionale-Stats',
#  '/en/squads/e0652b02/Juventus-Stats',
#  '/en/squads/dc56fe14/Milan-Stats',
#  '/en/squads/922493f3/Atalanta-Stats',
#  '/en/squads/1d8099f8/Bologna-Stats',
#  '/en/squads/cf74a709/Roma-Stats',
#  '/en/squads/421387cf/Fiorentina-Stats',
#  '/en/squads/7213da33/Lazio-Stats',
#  '/en/squads/105360fe/Torino-Stats',
#  '/en/squads/d48ad4ff/Napoli-Stats',
#  '/en/squads/21680aa4/Monza-Stats',
#  '/en/squads/658bf2de/Genoa-Stats',
#  '/en/squads/ffcbe334/Lecce-Stats',
#  '/en/squads/6a7ad59d/Frosinone-Stats',
#  '/en/squads/04eea015/Udinese-Stats',
#  '/en/squads/a3d88bd8/Empoli-Stats',
#  '/en/squads/e2befd26/Sassuolo-Stats',
#  '/en/squads/0e72edf2/Hellas-Verona-Stats',
#  '/en/squads/c4260e09/Cagliari-Stats',
#  '/en/squads/c5577084/Salernitana-Stats']

# %%
team_urls=[f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/d609edc0/Internazionale-Stats',
#  'https://fbref.com/en/squads/e0652b02/Juventus-Stats',
#  'https://fbref.com/en/squads/dc56fe14/Milan-Stats',
#  'https://fbref.com/en/squads/922493f3/Atalanta-Stats',
#  'https://fbref.com/en/squads/1d8099f8/Bologna-Stats',
#  'https://fbref.com/en/squads/cf74a709/Roma-Stats',
#  'https://fbref.com/en/squads/421387cf/Fiorentina-Stats',
#  'https://fbref.com/en/squads/7213da33/Lazio-Stats',
#  'https://fbref.com/en/squads/105360fe/Torino-Stats',
#  'https://fbref.com/en/squads/d48ad4ff/Napoli-Stats',
#  'https://fbref.com/en/squads/21680aa4/Monza-Stats',
#  'https://fbref.com/en/squads/658bf2de/Genoa-Stats',
#  'https://fbref.com/en/squads/ffcbe334/Lecce-Stats',
#  'https://fbref.com/en/squads/6a7ad59d/Frosinone-Stats',
#  'https://fbref.com/en/squads/04eea015/Udinese-Stats',
#  'https://fbref.com/en/squads/a3d88bd8/Empoli-Stats',
#  'https://fbref.com/en/squads/e2befd26/Sassuolo-Stats',
#  'https://fbref.com/en/squads/0e72edf2/Hellas-Verona-Stats',
#  'https://fbref.com/en/squads/c4260e09/Cagliari-Stats',
#  'https://fbref.com/en/squads/c5577084/Salernitana-Stats']

# %%
team_url=team_urls[0]

# %%
data=requests.get(team_url)

# %%
import pandas as pd

matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time          Comp         Round  Day Venue Result   GF   GA  \
# 0   2023-08-19  20:45       Serie A   Matchweek 1  Sat  Home      W  2.0  0.0
# 1   2023-08-28  20:45       Serie A   Matchweek 2  Mon  Away      W  2.0  0.0
# 2   2023-09-03  18:30       Serie A   Matchweek 3  Sun  Home      W  4.0  0.0
# 3   2023-09-16  18:00       Serie A   Matchweek 4  Sat  Home      W  5.0  1.0
# 35       NaN                 NaN  Head-to-Head                  NaN
# 36       NaN                 NaN  Head-to-Head                  NaN
# 37       NaN                 NaN  Head-to-Head                  NaN
# 38       NaN                 NaN  Head-to-Head           Leg 2 of 2
# 39       NaN                 NaN  Head-to-Head                  NaN
# 40       NaN                 NaN  Head-to-Head                  NaN
# 41       NaN                 NaN  Head-to-Head                  NaN
# 42       NaN                 NaN  Head-to-Head                  NaN
# 43       NaN                 NaN  Head-to-Head                  NaN
# 44       NaN                 NaN  Head-to-Head                  NaN
# 45       NaN                 NaN  Head-to-Head                  NaN
# 46       NaN                 NaN  Head-to-Head                  NaN
# 47       NaN                 NaN  Head-to-Head                  NaN
# 48       NaN                 NaN  Head-to-Head                  NaN

# %%
soup= BeautifulSoup(data.text)

# %%
links= soup.find_all("a")

# %%
links=[l.get("href") for l in links]

# %%
links=[l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/d609edc0/2023-2024/matchlogs/all_comps/shooting/Internazionale-Match-Logs-All-Competitions',
#  '/en/squads/d609edc0/2023-2024/matchlogs/all_comps/shooting/Internazionale-Match-Logs-All-Competitions',
#  '/en/squads/d609edc0/2023-2024/matchlogs/all_comps/shooting/Internazionale-Match-Logs-All-Competitions',
#  '/en/squads/d609edc0/2023-2024/matchlogs/all_comps/shooting/Internazionale-Match-Logs-All-Competitions']

# %%
data =requests.get(f"https://fbref.com{links[0]}")

# %%
shooting= pd.read_html(data.text,match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Internazionale                                                           \
#                 Date   Time          Comp        Round  Day Venue Result   GF
# 0         2023-08-19  20:45       Serie A  Matchweek 1  Sat  Home      W  2.0
# 1         2023-08-28  20:45       Serie A  Matchweek 2  Mon  Away      W  2.0
# 2         2023-09-03  18:30       Serie A  Matchweek 3  Sun  Home      W  4.0
# 3         2023-09-16  18:00       Serie A  Matchweek 4  Sat  Home      W  5.0
# 4         2023-09-20  21:00  Champions Lg  Group stage  Wed  Away      D  1.0
#
#                           ... Standard               Expected               \
#     GA          Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh
# 0  0.0             Monza  ...     17.2  1.0  0     0      2.7  2.7    0.12
# 1  0.0          Cagliari  ...     15.9  0.0  0     0      0.9  0.9    0.05
# 2  0.0        Fiorentina  ...     14.5  1.0  1     1      3.7  2.9    0.15
# 3  1.0             Milan  ...     15.2  1.0  1     1      2.6  1.8    0.14
# 4  1.0  es Real Sociedad  ...     14.7  0.0  0     0      0.5  0.5    0.09
#
#                Unnamed: 25_level_0
#   G-xG np:G-xG        Match Report
# 0 -0.7    -0.7        Match Report
# 1  1.1     1.1        Match Report
# 2  0.3     0.1        Match Report
# 3  2.4     2.2        Match Report
# 4  0.5     0.5        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns= shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-19  20:45       Serie A  Matchweek 1  Sat  Home      W  2.0  0.0
# 1  2023-08-28  20:45       Serie A  Matchweek 2  Mon  Away      W  2.0  0.0
# 2  2023-09-03  18:30       Serie A  Matchweek 3  Sun  Home      W  4.0  0.0
# 3  2023-09-16  18:00       Serie A  Matchweek 4  Sat  Home      W  5.0  1.0
# 4  2023-09-20  21:00  Champions Lg  Group stage  Wed  Away      D  1.0  1.0
#
#            Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0             Monza  ...  17.2  1.0   0      0  2.7   2.7     0.12  -0.7
# 1          Cagliari  ...  15.9  0.0   0      0  0.9   0.9     0.05   1.1
# 2        Fiorentina  ...  14.5  1.0   1      1  3.7   2.9     0.15   0.3
# 3             Milan  ...  15.2  1.0   1      1  2.6   1.8     0.14   2.4
# 4  es Real Sociedad  ...  14.7  0.0   0      0  0.5   0.5     0.09   0.5
#
#    np:G-xG  Match Report
# 0     -0.7  Match Report
# 1      1.1  Match Report
# 2      0.1  Match Report
# 3      2.2  Match Report
# 4      0.5  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
years= list(range(2023,2017,-1))

# %%
all_matches=[]

# %%
standings_url= "https://fbref.com/en/comps/11/Serie-A-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        
        data = requests.get(f"https://fbref.com{links[0]}") 
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Serie A"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 29
#      26 shooting.columns = shooting.columns.droplevel()
#      28 try:
# ---> 29     team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
#      30 except ValueError:
#      31     continue
#
# File D:\anacondar\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File D:\anacondar\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File D:\anacondar\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['FK'] not in index"

# %%
match_df=pd.concat(all_matches)

# %%
match_df
# Out:
#           Date   Time     Comp         Round  Day Venue Result   GF   GA  \
# 0   2023-08-19  20:45  Serie A   Matchweek 1  Sat  Home      W  2.0  0.0
# 1   2023-08-28  20:45  Serie A   Matchweek 2  Mon  Away      W  2.0  0.0
# 2   2023-09-03  18:30  Serie A   Matchweek 3  Sun  Home      W  4.0  0.0
# 3   2023-09-16  18:00  Serie A   Matchweek 4  Sat  Home      W  5.0  1.0
# 5   2023-09-24  12:30  Serie A   Matchweek 5  Sun  Away      W  1.0  0.0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 34  2018-04-21  20:45  Serie A  Matchweek 34  Sat  Away      W    1    0
# 35  2018-04-29  15:00  Serie A  Matchweek 35  Sun  Home      D    3    3
# 36  2018-05-06  15:00  Serie A  Matchweek 36  Sun  Away      L    0    2
# 37  2018-05-12  18:00  Serie A  Matchweek 37  Sat  Home      W    1    0
# 38  2018-05-20  18:00  Serie A  Matchweek 38  Sun  Away      L    0    1
#
#       Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 0        Monza  ...  Match Report    NaN  22.0   3.0  17.2  1.0  0     0
# 1     Cagliari  ...  Match Report    NaN  17.0   3.0  15.9  0.0  0     0
# 2   Fiorentina  ...  Match Report    NaN  20.0  10.0  14.5  1.0  1     1
# 3        Milan  ...  Match Report    NaN  13.0   6.0  15.2  1.0  1     1
# 5       Empoli  ...  Match Report    NaN  23.0   5.0  16.8  0.0  0     0
# ..         ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 34       Milan  ...  Match Report    NaN   5.0   1.0  32.6  0.0  0     0
# 35     Udinese  ...  Match Report    NaN  11.0   5.0  19.9  0.0  1     1
# 36        SPAL  ...  Match Report    NaN  12.0   3.0  26.6  2.0  0     0
# 37       Genoa  ...  Match Report    NaN  14.0   3.0  13.7  0.0  0     0
# 38      Chievo  ...  Match Report    NaN  12.0   1.0  18.7  0.0  0     0
#
#    Season            Team
# 0    2023  Internazionale
# 1    2023  Internazionale
# 2    2023  Internazionale
# 3    2023  Internazionale
# 5    2023  Internazionale
# ..    ...             ...
# 34   2023       Benevento
# 35   2023       Benevento
# 36   2023       Benevento
# 37   2023       Benevento
# 38   2023       Benevento
#
# [5040 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")
